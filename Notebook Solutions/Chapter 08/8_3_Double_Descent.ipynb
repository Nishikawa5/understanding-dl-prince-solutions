# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to c:\users\pichau\appdata\local\temp\pip-req-build-s70tqk4_
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from mnist1d==0.0.2.post16) (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from mnist1d==0.0.2.post16) (3.9.4)
# Requirement already satisfied: scipy in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (6.5.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2024.12.14)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->mnist1d==0.0.2.post16) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\pichau\anaconda3\envs\cuda_2025\lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml): started
#   Building wheel for mnist1d (pyproject.toml): finished with status 'done'
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14719 sha256=b4815712f1676df1df4a54de590c152db2fce6e363905a2ea7534b258f7a5d47
#   Stored in directory: C:\Users\pichau\AppData\Local\Temp\pip-ephem-wheel-cache-18mv3oml\wheels\c4\34\e0\a3b4376888d7486638e921a69788a6309c58168eb2b2183b5b
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\pichau\AppData\Local\Temp\pip-req-build-s70tqk4_'

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'], dtype=torch.float32)
  y_train = torch.tensor(data['y'].transpose(), dtype=torch.int64)
  x_test= torch.tensor(data['x_test'], dtype=torch.float32)
  y_test = torch.tensor(data['y_test'], dtype=torch.int64)

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
#
# - About 4000 parameters
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#
# - About 4000/2 parameters (according to Figure 8.10)
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#
# - About 4000 parameters (according to Figure 8.10)

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301555, train error 89.97,  test loss 2.303873, test error 90.75
# Epoch   100, train loss 1.923297, train error 73.70,  test loss 1.757293, test error 69.72
# Epoch   200, train loss 1.912648, train error 71.97,  test loss 1.736011, test error 69.35
# Epoch   300, train loss 1.890255, train error 71.47,  test loss 1.727908, test error 69.45
# Epoch   400, train loss 1.887722, train error 72.05,  test loss 1.724983, test error 68.80
# Epoch   500, train loss 1.885710, train error 71.32,  test loss 1.721064, test error 69.00
# Epoch   600, train loss 1.885268, train error 70.70,  test loss 1.717621, test error 68.50
# Epoch   700, train loss 1.887018, train error 71.45,  test loss 1.726583, test error 69.15
# Epoch   800, train loss 1.896137, train error 71.72,  test loss 1.721838, test error 68.78
# Epoch   900, train loss 1.884440, train error 70.82,  test loss 1.719372, test error 69.43
# Training model with   4 hidden variables
# Epoch     0, train loss 2.263261, train error 89.55,  test loss 2.258169, test error 89.50
# Epoch   100, train loss 1.750486, train error 64.57,  test loss 1.537298, test error 60.85
# Epoch   200, train loss 1.713596, train error 62.10,  test loss 1.512313, test error 58.40
# Epoch   300, train loss 1.710855, train error 62.10,  test loss 1.501831, test error 58.28
# Epoch   400, train loss 1.704248, train error 61.53,  test loss 1.499590, test error 58.53
# Epoch   500, train loss 1.702019, train error 61.25,  test loss 1.508854, test error 59.28
# Epoch   600, train loss 1.694077, train error 60.60,  test loss 1.494789, test error 57.97
# Epoch   700, train loss 1.695368, train error 61.05,  test loss 1.499776, test error 59.17
# Epoch   800, train loss 1.696649, train error 61.42,  test loss 1.509250, test error 59.03
# Epoch   900, train loss 1.684301, train error 59.55,  test loss 1.495315, test error 57.50
# Training model with   6 hidden variables
# Epoch     0, train loss 2.197133, train error 83.32,  test loss 2.167769, test error 81.78
# Epoch   100, train loss 1.629119, train error 57.62,  test loss 1.439342, test error 53.72
# Epoch   200, train loss 1.601763, train error 55.58,  test loss 1.426962, test error 53.28
# Epoch   300, train loss 1.605580, train error 56.42,  test loss 1.428511, test error 55.35
# Epoch   400, train loss 1.588923, train error 54.90,  test loss 1.414695, test error 53.42
# Epoch   500, train loss 1.578902, train error 55.25,  test loss 1.407737, test error 53.10
# Epoch   600, train loss 1.582021, train error 56.12,  test loss 1.412423, test error 53.90
# Epoch   700, train loss 1.578822, train error 55.35,  test loss 1.419021, test error 54.83
# Epoch   800, train loss 1.572834, train error 54.60,  test loss 1.406508, test error 53.33
# Epoch   900, train loss 1.579280, train error 54.38,  test loss 1.415563, test error 54.12
# Training model with   8 hidden variables
# Epoch     0, train loss 2.246077, train error 81.70,  test loss 2.237615, test error 80.75
# Epoch   100, train loss 1.579007, train error 55.78,  test loss 1.425974, test error 53.88
# Epoch   200, train loss 1.540257, train error 54.30,  test loss 1.418368, test error 53.28
# Epoch   300, train loss 1.519270, train error 53.60,  test loss 1.418849, test error 52.62
# Epoch   400, train loss 1.508465, train error 53.42,  test loss 1.436423, test error 53.30
# Epoch   500, train loss 1.499116, train error 52.80,  test loss 1.447258, test error 53.05
# Epoch   600, train loss 1.497130, train error 53.05,  test loss 1.448987, test error 52.83
# Epoch   700, train loss 1.496457, train error 53.10,  test loss 1.460344, test error 53.35
# Epoch   800, train loss 1.497428, train error 53.80,  test loss 1.463208, test error 53.28
# Epoch   900, train loss 1.487798, train error 52.40,  test loss 1.454552, test error 52.80
# Training model with  10 hidden variables
# Epoch     0, train loss 2.258236, train error 85.85,  test loss 2.245181, test error 86.20
# Epoch   100, train loss 1.452600, train error 48.90,  test loss 1.275510, test error 47.03
# Epoch   200, train loss 1.379553, train error 46.10,  test loss 1.216666, test error 45.35
# Epoch   300, train loss 1.354306, train error 45.50,  test loss 1.226231, test error 45.10
# Epoch   400, train loss 1.339458, train error 44.62,  test loss 1.224080, test error 45.05
# Epoch   500, train loss 1.334174, train error 45.00,  test loss 1.235558, test error 45.15
# Epoch   600, train loss 1.327172, train error 45.08,  test loss 1.239514, test error 44.88
# Epoch   700, train loss 1.327251, train error 45.22,  test loss 1.257359, test error 45.75
# Epoch   800, train loss 1.326524, train error 45.05,  test loss 1.257276, test error 46.50
# Epoch   900, train loss 1.322975, train error 45.53,  test loss 1.259277, test error 45.67
# Training model with  14 hidden variables
# Epoch     0, train loss 2.200375, train error 82.10,  test loss 2.167685, test error 80.30
# Epoch   100, train loss 1.408666, train error 47.70,  test loss 1.293640, test error 49.12
# Epoch   200, train loss 1.333905, train error 44.50,  test loss 1.265739, test error 46.95
# Epoch   300, train loss 1.302316, train error 44.47,  test loss 1.272692, test error 46.60
# Epoch   400, train loss 1.294936, train error 44.03,  test loss 1.305686, test error 48.15
# Epoch   500, train loss 1.276353, train error 43.17,  test loss 1.299367, test error 47.00
# Epoch   600, train loss 1.273817, train error 43.20,  test loss 1.307654, test error 47.05
# Epoch   700, train loss 1.270356, train error 43.70,  test loss 1.321479, test error 47.17
# Epoch   800, train loss 1.268619, train error 43.70,  test loss 1.323698, test error 47.67
# Epoch   900, train loss 1.263021, train error 44.03,  test loss 1.323886, test error 48.08
# Training model with  18 hidden variables
# Epoch     0, train loss 2.151932, train error 78.95,  test loss 2.145924, test error 78.97
# Epoch   100, train loss 1.320472, train error 43.47,  test loss 1.262236, test error 47.40
# Epoch   200, train loss 1.241167, train error 41.22,  test loss 1.294564, test error 47.58
# Epoch   300, train loss 1.185351, train error 40.38,  test loss 1.332691, test error 47.83
# Epoch   400, train loss 1.168166, train error 39.17,  test loss 1.368496, test error 48.00
# Epoch   500, train loss 1.145467, train error 38.03,  test loss 1.395193, test error 48.20
# Epoch   600, train loss 1.149408, train error 38.33,  test loss 1.446624, test error 49.78
# Epoch   700, train loss 1.122712, train error 37.75,  test loss 1.450294, test error 49.17
# Epoch   800, train loss 1.115822, train error 37.72,  test loss 1.480855, test error 49.47
# Epoch   900, train loss 1.114904, train error 38.30,  test loss 1.496163, test error 49.70
# Training model with  22 hidden variables
# Epoch     0, train loss 2.199918, train error 80.62,  test loss 2.198382, test error 81.55
# Epoch   100, train loss 1.323122, train error 44.12,  test loss 1.402924, test error 52.20
# Epoch   200, train loss 1.170687, train error 39.97,  test loss 1.398083, test error 51.35
# Epoch   300, train loss 1.098866, train error 37.97,  test loss 1.498988, test error 52.80
# Epoch   400, train loss 1.071079, train error 36.72,  test loss 1.577375, test error 53.45
# Epoch   500, train loss 1.042360, train error 36.05,  test loss 1.635287, test error 54.58
# Epoch   600, train loss 1.033199, train error 35.40,  test loss 1.656644, test error 53.70
# Epoch   700, train loss 1.025267, train error 35.62,  test loss 1.708550, test error 54.20
# Epoch   800, train loss 1.037201, train error 36.35,  test loss 1.746955, test error 53.60
# Epoch   900, train loss 1.022437, train error 34.88,  test loss 1.751819, test error 54.70
# Training model with  26 hidden variables
# Epoch     0, train loss 2.176327, train error 80.25,  test loss 2.166589, test error 80.82
# Epoch   100, train loss 1.205787, train error 39.75,  test loss 1.346745, test error 50.15
# Epoch   200, train loss 1.063261, train error 35.50,  test loss 1.408477, test error 50.55
# Epoch   300, train loss 0.990975, train error 34.12,  test loss 1.492818, test error 50.72
# Epoch   400, train loss 0.935528, train error 32.38,  test loss 1.551740, test error 50.88
# Epoch   500, train loss 0.904668, train error 31.22,  test loss 1.692721, test error 52.28
# Epoch   600, train loss 0.881662, train error 30.80,  test loss 1.774346, test error 52.53
# Epoch   700, train loss 0.861243, train error 29.88,  test loss 1.859504, test error 52.83
# Epoch   800, train loss 0.847879, train error 29.85,  test loss 1.893363, test error 52.40
# Epoch   900, train loss 0.839651, train error 29.53,  test loss 1.992097, test error 53.58
# Training model with  30 hidden variables
# Epoch     0, train loss 2.176402, train error 80.68,  test loss 2.148298, test error 80.57
# Epoch   100, train loss 1.150504, train error 37.08,  test loss 1.392185, test error 51.17
# Epoch   200, train loss 0.963207, train error 31.65,  test loss 1.550366, test error 51.65
# Epoch   300, train loss 0.880606, train error 29.55,  test loss 1.761473, test error 52.92
# Epoch   400, train loss 0.821876, train error 26.75,  test loss 1.929864, test error 53.80
# Epoch   500, train loss 0.783503, train error 26.20,  test loss 2.113261, test error 54.60
# Epoch   600, train loss 0.764837, train error 25.85,  test loss 2.292811, test error 55.00
# Epoch   700, train loss 0.735188, train error 24.10,  test loss 2.422088, test error 55.17
# Epoch   800, train loss 0.702202, train error 23.38,  test loss 2.494050, test error 55.35
# Epoch   900, train loss 0.694818, train error 23.85,  test loss 2.635792, test error 55.80
# Training model with  35 hidden variables
# Epoch     0, train loss 2.158288, train error 79.95,  test loss 2.160579, test error 82.05
# Epoch   100, train loss 1.026482, train error 33.62,  test loss 1.436757, test error 50.85
# Epoch   200, train loss 0.799675, train error 25.53,  test loss 1.737829, test error 54.45
# Epoch   300, train loss 0.719816, train error 23.90,  test loss 2.050879, test error 54.90
# Epoch   400, train loss 0.644838, train error 21.35,  test loss 2.298110, test error 54.03
# Epoch   500, train loss 0.588462, train error 19.70,  test loss 2.633689, test error 55.60
# Epoch   600, train loss 0.581120, train error 20.20,  test loss 2.888074, test error 55.72
# Epoch   700, train loss 0.538331, train error 19.03,  test loss 3.113525, test error 56.25
# Epoch   800, train loss 0.522416, train error 18.00,  test loss 3.287804, test error 55.25
# Epoch   900, train loss 0.551577, train error 20.07,  test loss 3.528308, test error 56.28
# Training model with  40 hidden variables
# Epoch     0, train loss 2.125897, train error 79.18,  test loss 2.081740, test error 78.75
# Epoch   100, train loss 0.943582, train error 31.60,  test loss 1.401331, test error 48.53
# Epoch   200, train loss 0.655568, train error 21.20,  test loss 1.919162, test error 52.72
# Epoch   300, train loss 0.508819, train error 16.25,  test loss 2.492326, test error 54.28
# Epoch   400, train loss 0.400932, train error 13.10,  test loss 3.179236, test error 55.30
# Epoch   500, train loss 0.410250, train error 14.00,  test loss 3.853388, test error 57.85
# Epoch   600, train loss 0.335429, train error 11.03,  test loss 4.430690, test error 56.97
# Epoch   700, train loss 0.314210, train error 10.40,  test loss 4.960586, test error 56.95
# Epoch   800, train loss 0.265272, train error 8.45,  test loss 5.556509, test error 57.72
# Epoch   900, train loss 0.236057, train error 7.18,  test loss 6.015152, test error 57.85
# Training model with  45 hidden variables
# Epoch     0, train loss 2.095026, train error 78.28,  test loss 2.066452, test error 77.07
# Epoch   100, train loss 0.809601, train error 25.10,  test loss 1.516970, test error 51.25
# Epoch   200, train loss 0.471515, train error 13.72,  test loss 2.244930, test error 52.67
# Epoch   300, train loss 0.313461, train error 9.80,  test loss 3.406454, test error 55.03
# Epoch   400, train loss 0.191624, train error 5.10,  test loss 4.634067, test error 55.10
# Epoch   500, train loss 0.118997, train error 2.78,  test loss 5.998571, test error 56.53
# Epoch   600, train loss 0.174906, train error 5.65,  test loss 7.155613, test error 57.35
# Epoch   700, train loss 0.169074, train error 6.05,  test loss 8.402789, test error 57.58
# Epoch   800, train loss 0.008939, train error 0.00,  test loss 9.169868, test error 57.75
# Epoch   900, train loss 0.006077, train error 0.00,  test loss 9.774658, test error 57.53
# Training model with  50 hidden variables
# Epoch     0, train loss 2.101547, train error 77.53,  test loss 2.086188, test error 77.20
# Epoch   100, train loss 0.736782, train error 22.78,  test loss 1.557473, test error 50.28
# Epoch   200, train loss 0.353691, train error 10.60,  test loss 2.631127, test error 53.25
# Epoch   300, train loss 0.190575, train error 5.38,  test loss 4.114066, test error 54.12
# Epoch   400, train loss 0.037438, train error 0.10,  test loss 5.801711, test error 55.55
# Epoch   500, train loss 0.014212, train error 0.00,  test loss 6.907197, test error 56.12
# Epoch   600, train loss 0.008746, train error 0.00,  test loss 7.578469, test error 56.12
# Epoch   700, train loss 0.006167, train error 0.00,  test loss 8.094587, test error 56.17
# Epoch   800, train loss 0.004792, train error 0.00,  test loss 8.499238, test error 56.20
# Epoch   900, train loss 0.003837, train error 0.00,  test loss 8.827963, test error 56.28
# Training model with  55 hidden variables
# Epoch     0, train loss 2.052120, train error 77.55,  test loss 1.981340, test error 77.12
# Epoch   100, train loss 0.608448, train error 18.75,  test loss 1.686354, test error 51.22
# Epoch   200, train loss 0.177516, train error 3.32,  test loss 3.162836, test error 54.33
# Epoch   300, train loss 0.032267, train error 0.05,  test loss 4.778709, test error 54.10
# Epoch   400, train loss 0.012784, train error 0.00,  test loss 5.669636, test error 54.22
# Epoch   500, train loss 0.007739, train error 0.00,  test loss 6.233404, test error 54.50
# Epoch   600, train loss 0.005357, train error 0.00,  test loss 6.634543, test error 54.65
# Epoch   700, train loss 0.004047, train error 0.00,  test loss 6.951742, test error 54.62
# Epoch   800, train loss 0.003213, train error 0.00,  test loss 7.205782, test error 54.72
# Epoch   900, train loss 0.002645, train error 0.00,  test loss 7.425045, test error 54.53
# Training model with  60 hidden variables
# Epoch     0, train loss 2.083018, train error 78.20,  test loss 2.030184, test error 76.68
# Epoch   100, train loss 0.503906, train error 14.82,  test loss 1.708882, test error 49.75
# Epoch   200, train loss 0.090576, train error 0.47,  test loss 3.290380, test error 51.92
# Epoch   300, train loss 0.018934, train error 0.00,  test loss 4.591439, test error 52.47
# Epoch   400, train loss 0.009108, train error 0.00,  test loss 5.246860, test error 52.65
# Epoch   500, train loss 0.005762, train error 0.00,  test loss 5.673387, test error 52.78
# Epoch   600, train loss 0.004114, train error 0.00,  test loss 5.992564, test error 52.92
# Epoch   700, train loss 0.003155, train error 0.00,  test loss 6.247938, test error 52.92
# Epoch   800, train loss 0.002548, train error 0.00,  test loss 6.454937, test error 53.00
# Epoch   900, train loss 0.002110, train error 0.00,  test loss 6.633331, test error 53.00
# Training model with  70 hidden variables
# Epoch     0, train loss 2.043438, train error 75.88,  test loss 2.013396, test error 76.95
# Epoch   100, train loss 0.356443, train error 8.95,  test loss 1.892908, test error 51.72
# Epoch   200, train loss 0.034203, train error 0.00,  test loss 3.492241, test error 53.38
# Epoch   300, train loss 0.010966, train error 0.00,  test loss 4.274700, test error 53.38
# Epoch   400, train loss 0.006160, train error 0.00,  test loss 4.705781, test error 53.53
# Epoch   500, train loss 0.004090, train error 0.00,  test loss 5.008504, test error 53.50
# Epoch   600, train loss 0.003022, train error 0.00,  test loss 5.238440, test error 53.58
# Epoch   700, train loss 0.002372, train error 0.00,  test loss 5.421154, test error 53.62
# Epoch   800, train loss 0.001934, train error 0.00,  test loss 5.576225, test error 53.67
# Epoch   900, train loss 0.001624, train error 0.00,  test loss 5.706752, test error 53.65
# Training model with  80 hidden variables
# Epoch     0, train loss 2.024973, train error 74.97,  test loss 1.975155, test error 75.78
# Epoch   100, train loss 0.241988, train error 4.18,  test loss 2.099126, test error 52.28
# Epoch   200, train loss 0.020857, train error 0.00,  test loss 3.467264, test error 53.03
# Epoch   300, train loss 0.008400, train error 0.00,  test loss 4.056923, test error 53.20
# Epoch   400, train loss 0.004924, train error 0.00,  test loss 4.398290, test error 53.53
# Epoch   500, train loss 0.003374, train error 0.00,  test loss 4.637823, test error 53.47
# Epoch   600, train loss 0.002532, train error 0.00,  test loss 4.826165, test error 53.33
# Epoch   700, train loss 0.002007, train error 0.00,  test loss 4.980835, test error 53.35
# Epoch   800, train loss 0.001653, train error 0.00,  test loss 5.108942, test error 53.28
# Epoch   900, train loss 0.001397, train error 0.00,  test loss 5.222258, test error 53.45
# Training model with  90 hidden variables
# Epoch     0, train loss 2.011041, train error 74.00,  test loss 1.946041, test error 75.22
# Epoch   100, train loss 0.135883, train error 0.95,  test loss 2.164229, test error 50.65
# Epoch   200, train loss 0.015037, train error 0.00,  test loss 3.187619, test error 51.85
# Epoch   300, train loss 0.006593, train error 0.00,  test loss 3.607527, test error 51.58
# Epoch   400, train loss 0.004026, train error 0.00,  test loss 3.869411, test error 51.67
# Epoch   500, train loss 0.002834, train error 0.00,  test loss 4.059293, test error 51.70
# Epoch   600, train loss 0.002154, train error 0.00,  test loss 4.205627, test error 51.83
# Epoch   700, train loss 0.001722, train error 0.00,  test loss 4.325352, test error 51.72
# Epoch   800, train loss 0.001425, train error 0.00,  test loss 4.427571, test error 51.72
# Epoch   900, train loss 0.001209, train error 0.00,  test loss 4.515344, test error 51.70
# Training model with 100 hidden variables
# Epoch     0, train loss 1.995170, train error 74.95,  test loss 1.931915, test error 74.85
# Epoch   100, train loss 0.081397, train error 0.05,  test loss 2.190753, test error 50.55
# Epoch   200, train loss 0.011890, train error 0.00,  test loss 3.000578, test error 50.88
# Epoch   300, train loss 0.005570, train error 0.00,  test loss 3.343416, test error 51.20
# Epoch   400, train loss 0.003485, train error 0.00,  test loss 3.560074, test error 51.28
# Epoch   500, train loss 0.002479, train error 0.00,  test loss 3.718939, test error 51.55
# Epoch   600, train loss 0.001904, train error 0.00,  test loss 3.844380, test error 51.50
# Epoch   700, train loss 0.001529, train error 0.00,  test loss 3.948606, test error 51.50
# Epoch   800, train loss 0.001270, train error 0.00,  test loss 4.035932, test error 51.45
# Epoch   900, train loss 0.001082, train error 0.00,  test loss 4.111552, test error 51.45
# Training model with 120 hidden variables
# Epoch     0, train loss 1.970353, train error 73.30,  test loss 1.901584, test error 74.00
# Epoch   100, train loss 0.052054, train error 0.00,  test loss 2.229908, test error 50.00
# Epoch   200, train loss 0.009519, train error 0.00,  test loss 2.840000, test error 49.58
# Epoch   300, train loss 0.004735, train error 0.00,  test loss 3.116542, test error 49.58
# Epoch   400, train loss 0.003027, train error 0.00,  test loss 3.296561, test error 49.80
# Epoch   500, train loss 0.002182, train error 0.00,  test loss 3.430074, test error 49.88
# Epoch   600, train loss 0.001686, train error 0.00,  test loss 3.535028, test error 49.83
# Epoch   700, train loss 0.001362, train error 0.00,  test loss 3.622953, test error 49.72
# Epoch   800, train loss 0.001137, train error 0.00,  test loss 3.697198, test error 49.70
# Epoch   900, train loss 0.000972, train error 0.00,  test loss 3.761983, test error 49.72
# Training model with 140 hidden variables
# Epoch     0, train loss 1.963202, train error 73.57,  test loss 1.876558, test error 73.43
# Epoch   100, train loss 0.041426, train error 0.00,  test loss 2.126845, test error 48.70
# Epoch   200, train loss 0.008415, train error 0.00,  test loss 2.612499, test error 48.83
# Epoch   300, train loss 0.004245, train error 0.00,  test loss 2.842563, test error 48.65
# Epoch   400, train loss 0.002733, train error 0.00,  test loss 2.990745, test error 48.58
# Epoch   500, train loss 0.001980, train error 0.00,  test loss 3.102533, test error 48.55
# Epoch   600, train loss 0.001536, train error 0.00,  test loss 3.190374, test error 48.65
# Epoch   700, train loss 0.001245, train error 0.00,  test loss 3.262911, test error 48.60
# Epoch   800, train loss 0.001041, train error 0.00,  test loss 3.325511, test error 48.60
# Epoch   900, train loss 0.000891, train error 0.00,  test loss 3.378807, test error 48.58
# Training model with 160 hidden variables
# Epoch     0, train loss 1.956575, train error 72.68,  test loss 1.894616, test error 74.10
# Epoch   100, train loss 0.029890, train error 0.00,  test loss 2.153518, test error 49.47
# Epoch   200, train loss 0.007431, train error 0.00,  test loss 2.573505, test error 49.35
# Epoch   300, train loss 0.003886, train error 0.00,  test loss 2.781978, test error 49.50
# Epoch   400, train loss 0.002549, train error 0.00,  test loss 2.920190, test error 49.60
# Epoch   500, train loss 0.001863, train error 0.00,  test loss 3.022485, test error 49.45
# Epoch   600, train loss 0.001452, train error 0.00,  test loss 3.105551, test error 49.50
# Epoch   700, train loss 0.001182, train error 0.00,  test loss 3.174193, test error 49.53
# Epoch   800, train loss 0.000991, train error 0.00,  test loss 3.232674, test error 49.47
# Epoch   900, train loss 0.000850, train error 0.00,  test loss 3.283285, test error 49.45
# Training model with 180 hidden variables
# Epoch     0, train loss 1.919368, train error 70.28,  test loss 1.858523, test error 72.07
# Epoch   100, train loss 0.024522, train error 0.00,  test loss 1.995189, test error 47.45
# Epoch   200, train loss 0.006644, train error 0.00,  test loss 2.341382, test error 47.28
# Epoch   300, train loss 0.003546, train error 0.00,  test loss 2.515433, test error 47.50
# Epoch   400, train loss 0.002348, train error 0.00,  test loss 2.631413, test error 47.58
# Epoch   500, train loss 0.001726, train error 0.00,  test loss 2.719912, test error 47.55
# Epoch   600, train loss 0.001351, train error 0.00,  test loss 2.789672, test error 47.60
# Epoch   700, train loss 0.001102, train error 0.00,  test loss 2.848531, test error 47.40
# Epoch   800, train loss 0.000926, train error 0.00,  test loss 2.898480, test error 47.47
# Epoch   900, train loss 0.000796, train error 0.00,  test loss 2.942239, test error 47.45
# Training model with 200 hidden variables
# Epoch     0, train loss 1.929017, train error 69.85,  test loss 1.843396, test error 71.88
# Epoch   100, train loss 0.021617, train error 0.00,  test loss 2.016658, test error 48.40
# Epoch   200, train loss 0.006176, train error 0.00,  test loss 2.339052, test error 48.78
# Epoch   300, train loss 0.003344, train error 0.00,  test loss 2.504293, test error 48.85
# Epoch   400, train loss 0.002231, train error 0.00,  test loss 2.615686, test error 48.88
# Epoch   500, train loss 0.001646, train error 0.00,  test loss 2.698609, test error 48.90
# Epoch   600, train loss 0.001293, train error 0.00,  test loss 2.765409, test error 48.95
# Epoch   700, train loss 0.001057, train error 0.00,  test loss 2.821132, test error 48.90
# Epoch   800, train loss 0.000890, train error 0.00,  test loss 2.869355, test error 48.95
# Epoch   900, train loss 0.000766, train error 0.00,  test loss 2.911580, test error 48.97
# Training model with 250 hidden variables
# Epoch     0, train loss 1.891382, train error 69.55,  test loss 1.828899, test error 71.10
# Epoch   100, train loss 0.016906, train error 0.00,  test loss 1.898262, test error 47.42
# Epoch   200, train loss 0.005336, train error 0.00,  test loss 2.149931, test error 47.22
# Epoch   300, train loss 0.002972, train error 0.00,  test loss 2.281103, test error 47.42
# Epoch   400, train loss 0.002005, train error 0.00,  test loss 2.370178, test error 47.33
# Epoch   500, train loss 0.001493, train error 0.00,  test loss 2.438688, test error 47.35
# Epoch   600, train loss 0.001179, train error 0.00,  test loss 2.493782, test error 47.25
# Epoch   700, train loss 0.000968, train error 0.00,  test loss 2.540479, test error 47.20
# Epoch   800, train loss 0.000818, train error 0.00,  test loss 2.580109, test error 47.08
# Epoch   900, train loss 0.000706, train error 0.00,  test loss 2.615119, test error 47.12
# Training model with 300 hidden variables
# Epoch     0, train loss 1.903512, train error 69.68,  test loss 1.840804, test error 70.53
# Epoch   100, train loss 0.014969, train error 0.00,  test loss 1.840078, test error 45.92
# Epoch   200, train loss 0.004913, train error 0.00,  test loss 2.063634, test error 45.95
# Epoch   300, train loss 0.002779, train error 0.00,  test loss 2.185840, test error 46.15
# Epoch   400, train loss 0.001892, train error 0.00,  test loss 2.268262, test error 46.25
# Epoch   500, train loss 0.001413, train error 0.00,  test loss 2.331807, test error 46.33
# Epoch   600, train loss 0.001118, train error 0.00,  test loss 2.383108, test error 46.38
# Epoch   700, train loss 0.000920, train error 0.00,  test loss 2.425962, test error 46.42
# Epoch   800, train loss 0.000778, train error 0.00,  test loss 2.463092, test error 46.40
# Epoch   900, train loss 0.000672, train error 0.00,  test loss 2.495655, test error 46.55
# Training model with 400 hidden variables
# Epoch     0, train loss 1.826554, train error 64.95,  test loss 1.757248, test error 68.10
# Epoch   100, train loss 0.011736, train error 0.00,  test loss 1.790429, test error 46.38
# Epoch   200, train loss 0.004180, train error 0.00,  test loss 1.970375, test error 46.40
# Epoch   300, train loss 0.002421, train error 0.00,  test loss 2.069187, test error 46.20
# Epoch   400, train loss 0.001666, train error 0.00,  test loss 2.136778, test error 46.12
# Epoch   500, train loss 0.001255, train error 0.00,  test loss 2.188967, test error 46.17
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.231280, test error 46.08
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.267172, test error 46.15
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.298326, test error 46.08
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.325571, test error 45.97

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
